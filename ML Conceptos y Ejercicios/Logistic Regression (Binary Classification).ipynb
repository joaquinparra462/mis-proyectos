# %% [markdown]
# # Logistic Regression (Binary Classification)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/codebasics/py/raw/refs/heads/master/ML/7_logistic_reg/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['age'],df['bought_insurance'])

# %%
#sigue una funcion sigmoide
#Primero se divide la data en train,test

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
#se entrena el modelo
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict_proba(X_test)
# Out:
# array([[0.98509253, 0.01490747],
#        [0.90261563, 0.09738437],
#        [0.9435292 , 0.0564708 ],
#        [0.01152332, 0.98847668],
#        [0.13030353, 0.86969647],
#        [0.07673557, 0.92326443]])

# %%
model.score(X_test, y_test)
# Out:
# 0.6666666666666666
